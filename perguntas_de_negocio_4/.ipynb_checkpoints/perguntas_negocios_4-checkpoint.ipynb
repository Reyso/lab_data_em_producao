# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv('dataset/kc_house_data.csv')

# %% [markdown]
# ## 1- Crie uma nova coluna chamada: 'dormitory_type'
#     - se o valor da coluna "bedrooms" == 1 -> 'studio'
#     - se o valor da coluna "bedrooms" == 2 -> 'apartament'
#     - se o valor da coluna "bedrooms" > 2 -> 'house'

# %%
data['dormitory_type'] = data['bedrooms'].apply([lambda x : 'studio' if x ==1 else
                                                                        'apartament' if x == 2 else
                                                                        'house' if x >2 else
                                                                         np.NaN])

# %%
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %% [markdown]
# ## 2 - faça um gŕafico de barras que repesente a soma dos preços pelos números de quartos

# %%
data_temp = data[['bedrooms','price']].groupby('bedrooms').sum().reset_index(); data_temp
# Out:
#     bedrooms         price
# 0          0  5.323550e+06
# 1          1  6.321093e+07
# 2          2  1.107789e+09
# 3          3  4.580264e+09
# 4          4  4.372957e+09
# 5          5  1.259346e+09
# 6          6  2.245416e+08
# 7          7  3.614502e+07
# 8          8  1.436600e+07
# 9          9  5.363999e+06
# 10        10  2.458000e+06
# 11        11  5.200000e+05
# 12        33  6.400000e+05

# %%
sns.barplot(data = data_temp , 
            x = 'bedrooms',
            y = 'price')
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %% [markdown]
# ## 3 - Faça um gráfico de linhas que represente a média dos preços pelo ano de construção dos imóveis

# %%
data_temp = data[['price','yr_built']].groupby('yr_built').mean().reset_index()

# %%
data_temp['price'].max()
# Out:
# 772050.0

# %%
plt.figure(figsize=(10,5))
fig1 = sns.lineplot(data = data_temp,
            x = 'yr_built',
            y = 'price',
            legend='auto')
yticks = np.arange(300000,782050.0,20000)
xticks = np.arange(1900,2021,10)
plt.yticks(yticks)
plt.xticks(xticks,rotation = 0)
plt.show()

# %% [markdown]
# ## 4 - faça um gráfico de barras que represente a média dos preços pelo tipo dos dormitório

# %%
data_temp = data[['price','dormitory_type']].groupby('dormitory_type').mean().reset_index(); data_temp
# Out:
#   dormitory_type          price
# 0     apartament  401372.681884
# 1          house  563092.211899
# 2         studio  317642.884422

# %%
data_temp = data[['price','dormitory_type']].groupby('dormitory_type').mean().reset_index(); data_temp

plt.figure(figsize=(10,5))
fig3 =sns.barplot(data = data_temp,
           x = 'dormitory_type',
           y = 'price')
plt.yticks(np.arange(50000,603092,60000))
plt.title('Média dos preços por dormitório')
plt.show()

# %% [markdown]
# ## 5 - Faça um gráfico de linha que mostre a evolução da média dos preços pelo ano da reforma dos imóveis, a partir do ano de 1930

# %%
df = data.loc[data['yr_renovated']> 1930,['price','yr_renovated']]
data_temp = df[['price','yr_renovated']].groupby('yr_renovated').mean().reset_index();data_temp
# Out:
#     yr_renovated          price
# 0           1934  459950.000000
# 1           1940  378400.000000
# 2           1944  521000.000000
# 3           1945  398666.666667
# 4           1946  351137.500000
# ..           ...            ...
# 64          2011  607496.153846
# 65          2012  625181.818182
# 66          2013  664663.513514
# 67          2014  654756.252747
# 68          2015  658843.750000
#
# [69 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))

fig4 = sns.lineplot(data = data_temp,
            x = 'yr_renovated',
            y = 'price')

# %% [markdown]
# ## 6 - Faça uma tabela que mostre a média dos preços por ano de construção e tipo de dormitórios dos imóveis.

# %%
df = data[['price','dormitory_type']].groupby('dormitory_type').mean().reset_index(); df.head()
# Out:
#   dormitory_type          price
# 0     apartament  401372.681884
# 1          house  563092.211899
# 2         studio  317642.884422

# %% [markdown]
# ## 7 Crie um dashboard com os gráficos das questões 02,03,04 ( 1linha e 2col embaixo)

# %%
fig = plt.figure(figsize=(24,12))
gs = gridspec.GridSpec(2,2,figure=fig)


ax1 = fig.add_subplot(gs[1,0])
ax2 = fig.add_subplot(gs[0,:])
ax3 = fig.add_subplot(gs[1,1])


# Gráfico Q02
data_temp = data[['bedrooms','price']].groupby('bedrooms').sum().reset_index();
ax1.bar(data_temp['bedrooms'],data_temp['price']);


# Gráfico Q03
data_temp = data[['price','yr_built']].groupby('yr_built').mean().reset_index()
ax2.plot(data_temp['yr_built'],data_temp['price'],)
yticks = np.arange(300000,810000.0,100000)
ax2.set_yticks(yticks)
ax2.set_xlabel('Year built')
ax2.set_ylabel('Price')

# Grafico Q04
data_temp = data[['price','dormitory_type']].groupby('dormitory_type').mean().reset_index();
ax3.bar(data_temp['dormitory_type'], data_temp['price'], color = ['r','b','y'] )
#sns.barplot(data = data_temp,x = 'dormitory_type',y = 'price')
yticks = np.arange(50000,603092,60000)
ax3.set_yticks(yticks)

# %% [markdown]
# ## 8 - Crie um Dashboard com os gráficos das questões 02,04 (1,2)

# %%
fig = plt.figure(figsize=(24,12))
gs = gridspec.GridSpec(ncols=2, nrows = 2, figure= fig)

ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[0,1])

# Gráfico Q02
data_temp = data[['bedrooms','price']].groupby('bedrooms').sum().reset_index();
ax1.bar(data_temp['bedrooms'],data_temp['price']);


# Gráfico Q03
data_temp = data[['price','yr_built']].groupby('yr_built').mean().reset_index()
ax2.plot(data_temp['yr_built'],data_temp['price'],)
yticks = np.arange(300000,810000.0,100000)
ax2.set_yticks(yticks)
ax2.set_xlabel('Year built')
ax2.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# ## 9 crie um dashboard com os gráficos das perguntas 03,05 ( 2,1)

# %%
fig = plt.figure(figsize=(24,12))
gs = gridspec.GridSpec(2,1, figure = fig)


ax1 = fig.add_subplot(gs[0,0])
ax2 = fig.add_subplot(gs[1,0])

# Gráfico Q03
data_temp = data[['price','yr_built']].groupby('yr_built').mean().reset_index()
ax1.plot(data_temp['yr_built'],data_temp['price'],)
yticks = np.arange(300000,810000.0,100000)
ax1.set_yticks(yticks)
ax1.set_xlabel('Year built')
ax1.set_ylabel('Price')

# Gráfico Q05
df = data.loc[data['yr_renovated']> 1930,['price','yr_renovated']]
data_temp = df[['price','yr_renovated']].groupby('yr_renovated').mean().reset_index()
sns.lineplot(data = data_temp,
            x = 'yr_renovated',
            y = 'price', ax= ax2)
#ax2.plot(data_temp['yr_renovated'], data_temp['price'])
ax2.set_yscale('linear')

# %% [markdown]
# ## 10 - Faça um gráfico com tamanho dos pontos sendo igual ao tamanho da sala de estar

# %%
import plotly.express as px

houses =  data[['id','lat','long','price','sqft_living']].copy()

fig = px.scatter_mapbox(houses,
                     lat= 'lat', lon='long',
                     size='sqft_living',
                     color_continuous_scale = px.colors.cyclical.IceFire,
                     size_max = 15,
                     zoom = 10)

fig.update_layout(mapbox_style = 'open-street-map')
fig.update_layout(height = 600, margin = {'r':0,'l':0,'t':0,'b':0})
